# %% [markdown]
# # 00 - Installation and Setup
#
# Welcome to Delphos! Before you can run the rest of the tutorials, you need to ensure that the `Delphos` python package is installed in your environment.
#
# If you are reading this inside Jupyter Lab, you might have already installed it! Let's verify everything is set up correctly.

# %% [markdown]
# ## 1. Installing Delphos
#
# If you haven't installed Delphos yet, you can run the following cell. It uses the `-e` (editable) flag, which means any changes you make to the Delphos source code will be immediately reflected without needing to reinstall.
#
# *(Note: The `%pip` magic command ensures that the package is installed directly into this Jupyter kernel's environment. **If the import in the next cell fails, please restart your Jupyter kernel** to allow it to detect the newly installed package).*

# %%
# Install the package located in the parent directory (Delphos root)
# %pip install -e ..
# Out:
# Obtaining file:///Users/gnova/Developer/Main-Delphos/Delphos
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for delphos (pyproject.toml) ... done
#   Created wheel for delphos: filename=delphos-0.1.0-0.editable-py3-none-any.whl size=1938 sha256=bebe8a6ed80f565a7ccd0deafafbd3ce89365233e0738f8d68b2d9af88611f1f
#   Stored in directory: /private/var/folders/xv/k3gzdbk96pq928y4x8pxhsgsqf8dzx/T/pip-ephem-wheel-cache-qfw6k43b/wheels/41/bc/73/8b899070f9498d2cd28c395d068b03e82aeacecf4d6c25044d
# Successfully built delphos
# ...
#   Attempting uninstall: delphos
#     Found existing installation: delphos 0.1.0
#     Uninstalling delphos-0.1.0:
#       Successfully uninstalled delphos-0.1.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Verifying the Installation
#
# Let's import the package and check that it successfully loads the agent and the default catalogue.

# %%
import delphos as dp

print("Delphos successfully imported!")

# Load the default agent
agent = dp.load_agent()
print("Agent loaded successfully! Device:", agent.agent.device)

# Load the global catalogue
catalogue = dp.data.registry.load_global_catalogue()
print(f"Global catalogue loaded! It contains {catalogue.n_attributes} attributes and {catalogue.n_covariates} covariates.")
# Out:
# Delphos successfully imported!
# Agent loaded successfully! Device: cpu
# Global catalogue loaded! It contains 7 attributes and 7 covariates.

# %% [markdown]
# ## 3. Verifying R and Apollo (Optional)
#
# Since Delphos orchestrates R scripts in the background, you will need R and the `apollo` package installed on your machine if you want to run **estimations**.
#
# If you only want to *generate* proposals without estimating them, you do not need R!
#
# Let's check if R is accessible from your terminal:

# %%
# !Rscript --version
# Out:
# Rscript (R) version 4.5.1 (2025-06-13)

# %% [markdown]
# If the cell above printed the R version (e.g., `R scripting front-end version 4.x.x`), you are perfectly set up to run estimation!
#
# You can now proceed to **`01_getting_started.ipynb`**.
